# %%
import numpy as np
import pandas as pd
matches = pd.read_csv('matches.csv')
deliveries = pd.read_csv('deliveries.csv')
print(matches.head())
print(deliveries.head())
ques1 = len(matches[matches['season'] == 2008])
print("First question answer:",ques1)
city_match_counts = matches['city'].value_counts()
print("third question answer:")
print(city_match_counts)
max_city = city_match_counts.idxmax()
max_matches = city_match_counts.max()
min_city = city_match_counts.idxmin()
min_matches = city_match_counts.min()
print("question 2 answer:")
print("City with minimum matches:", min_city, min_matches)
print("City with maximum matches:", max_city, max_matches)
print("question 4 answer:")
toss_tally = matches.groupby(['toss_winner', 'toss_decision']).size()
print(toss_tally)
print("question 5 answer:")
toss_result_counts = matches['result'].value_counts()
print(toss_result_counts)
print("question 7 answer:")
max_no_runs = matches['win_by_runs'].max()
max_team = matches['win_by_runs'].idxmax()
min_no_runs = matches['win_by_runs'].min()
min_team = matches['win_by_runs'].idxmin()
print("the team which won the match by the highest and lowest number of runs:",max_no_runs,max_team,min_no_runs,min_team )
print("question 8 answer:")
average1 = matches['win_by_runs'].mean()
median1 = matches['win_by_runs'].median()
standard_deviation = matches['win_by_runs'].std()
#print("Mean:" +average1 + "median:" +median1+"standard deviation:" +standard_deviation)
print("question 9 answer:")
highest1 = matches['win_by_runs'].max()
lowest1 = matches['win_by_runs'].min()
highest_location = matches['win_by_runs'].idxmax()
lowest_location = matches['win_by_runs'].idxmin()
print(highest1, lowest1, highest_location, lowest_location)
print("question 10 answer:")
playerof_match_counts = matches['player_of_match'].value_counts()
print(playerof_match_counts)
player_list1 = playerof_match_counts > 3
print(player_list1)
print("question 11 answer:")
six_deliveries = deliveries[deliveries['batsman_runs'] == 6]
print(six_deliveries)
print("question 12 answer:")
avg_allvenues = deliveries['total_runs'].mean()
print(avg_allvenues)
print("question 13 answer:")
#all_umpires = deliveries['umpire1'+'umpire2' +'umpire3']
#print(all_umpires)
#max_umpire = all_umpires.idxmax()
#print(max_umpire)
print("question 14 answer:")
no_matches_per_season = matches['season'].value_counts()
print(no_matches_per_season)
print("question 15 answer:")
print("question 16 answer:")
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...
